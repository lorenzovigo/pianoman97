# %%
from IPython.core.display import HTML
def css_styling():   
    styles = open("styles/custom.css", "r").read() 
    return HTML(styles)

# %% [markdown]
# # 1 Introduction to MongoDB
# <small>This introduction is partially inspired on the notes of Alberto Negron's [blog](http://altons.github.io/python/2013/01/21/gentle-introduction-to-mongodb-using-pymongo/)</small>

# %% [markdown]
# MongoDB is a document-oriented database, part of the NoSQL family of database systems. MongoDB stores structured data as JSON-like structures. From a pythonic point of view it is like storing dictionary data structures. One of its main feature is its schema-less feature, i.e. it supports dynamic schemas. A schema in a relational database informally refer to the structure of the data it stores, i.e. what kind of data, which tables, which relations, etc.

# %% [markdown]
# First of all let us configure the MongoDB system.
#
# + Download mongoDB.
#
# https://www.mongodb.com/download-center/community
#
# + Create data directory:
#
# `sudo mkdir -p /data/db`
# + Check that the server works
#
# `sudo ./mongod --nojournal &`
#
# + Check the connection to the server:
#
# in another terminal write `mongo` , check that it does not raise any error and exit the console.
# + Close the mongo daemon (mongod).
#         You may have to kill mongod with
#
# `killall mongod`
#
#         and remove the lock on the daemon,
# `rm /data/db/mongod.lock`
#
# + Let us configure a little the data base by configuring the path of the data storage and log files. Create a [mongo.conf](./mongo.conf) file such as the one provided  and start the server using the following command:
#
# `mongod --config=./mongo.conf --nojournal &`
#
# + Install pymongo
#
# `pip install pymongo`

# %% [markdown]
# ### Connect to a MongoDB database

# %%
import pymongo

# Connection to Mongo DB
try:
    conn=pymongo.MongoClient()
    print ("Connected successfully!!!")
except pymongo.errors.ConnectionFailure as e:
    print ("Could not connect to MongoDB: %s" % e) 
conn
# Out:
# Connected successfully!!!
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %% [markdown]
# We can **create** a database using attribute access <span style = "font-family:Courier;"> db = conn.name_db</span> or dictionary acces <span style = "font-family:Courier;"> db = conn[name_db]</span>.

# %%
#Create a database using db = conn.name_db or dictionary access db = conn['name_db']
db = conn['ADS']
print (db)
conn.database_names()
#Empty databases do not show
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), u'ADS')
# [u'TripAdvisor',
#  u'admin',
#  u'config',
#  u'db_enquestes',
#  u'foodb',
#  u'local',
#  u'twitter']

# %% [markdown]
# A database stores a **collection**. A collection is a group of documents stored in MongoDB, and can be thought of as the equivalent of a table in a relational database. Getting a collection in PyMongo works the same as getting a database:

# %%
collection = db.edu
db.collection_names()
#Empty collections do not show
# Out:
# []

# %% [markdown]
# MongoDB stores structured data as JSON-like documents, using dynamic schemas (called BSON), rather than predefined schemas. An element of data is called a document, and documents are stored in collections. One collection may have any number of documents.
#
# Compared to relational databases, we could say collections are like tables, and documents are like records. But there is one big difference: every record in a table has the same fields (with, usually, differing values) in the same order, while each document in a collection can have completely different fields from the other documents.
#
# All you really need to know when you're using Python, however, is that documents are Python dictionaries that can have strings as keys and can contain various primitive types (int, float,unicode, datetime) as well as other documents (Python dicts) and arrays (Python lists).
#
# To insert some data into MongoDB, all we need to do is create a dict and call .insert() on the collection object. Let us exemplify this process by getting some DatFrame and storing it in the collection.

# %%
import pandas as pd
df = pd.read_csv('./educ_figdp_1_Data.csv',na_values=':')
df.head(5)
# Out:
#    TIME                            GEO  \
# 0  2000  European Union (28 countries)
# 1  2001  European Union (28 countries)
# 2  2002  European Union (28 countries)
# 3  2003  European Union (28 countries)
# 4  2004  European Union (28 countries)
#
#                                             INDIC_ED  Value Flag and Footnotes
# 0  Total public expenditure on education as % of ...    NaN                NaN
# 1  Total public expenditure on education as % of ...    NaN                NaN
# 2  Total public expenditure on education as % of ...   5.00                  e
# 3  Total public expenditure on education as % of ...   5.03                  e
# 4  Total public expenditure on education as % of ...   4.95                  e

# %%
df.to_dict("records")
# Out:
# [{'Flag and Footnotes': nan,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': nan},
#  {'Flag and Footnotes': nan,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': nan},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 5.0},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 5.03},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 4.95},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 4.92},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 4.91},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 4.92},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 5.04},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 5.38},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 5.41},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 5.25},
#  {'Flag and Footnotes': 's',
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 4.91},
#  {'Flag and Footnotes': 's',
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 4.99},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 5.0},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 5.04},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 4.95},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 4.92},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 4.91},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 4.93},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 5.04},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 5.38},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 5.41},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 5.25},
#  {'Flag and Footnotes': 's',
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 4.94},
#  {'Flag and Footnotes': 's',
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 5.02},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 5.03},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 5.06},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 4.98},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 4.95},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 4.93},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 4.95},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 5.06},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 5.41},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 5.46},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 5.31},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': nan},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': nan},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 4.87},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 4.89},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 4.8},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 4.72},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 4.69},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 4.79},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 4.94},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 5.31},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 5.28},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 5.15},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': nan},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': nan},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 4.86},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 4.89},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 4.8},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 4.72},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 4.69},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 4.79},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 4.94},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 5.31},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 5.28},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 5.15},
#  {'Flag and Footnotes': 'u',
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': nan},
#  {'Flag and Footnotes': 's',
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 4.98},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 5.01},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 5.04},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 4.96},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 4.89},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 4.87},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 4.81},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 4.95},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 5.32},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 5.29},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 5.16},
#  {'Flag and Footnotes': 'u',
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': nan},
#  {'Flag and Footnotes': 's',
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 4.97},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 5.0},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 5.04},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 4.95},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 4.89},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 4.87},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 4.8},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 4.94},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 5.32},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 5.28},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 5.15},
#  {'Flag and Footnotes': 'u',
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': nan},
#  {'Flag and Footnotes': 'i',
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 5.99},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 6.09},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 6.02},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 5.95},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 5.92},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 5.98},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 6.0},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 6.43},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 6.57},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 6.58},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 6.55},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 3.88},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 3.7},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 3.94},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 4.09},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 4.4},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 4.25},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 4.04},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 3.88},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 4.44},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 4.58},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 4.1},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 3.82},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 3.83},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 3.93},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 4.15},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 4.32},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 4.2},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 4.08},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 4.42},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 4.05},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 3.92},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 4.36},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 4.25},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 4.51},
#  {'Flag and Footnotes': 'i',
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 8.28},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 8.44},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 8.44},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 8.33},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 8.43},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 8.3},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 7.97},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 7.81},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 7.68},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 8.74},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 8.81},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 8.75},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 4.45},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 4.51},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 4.72},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 4.74},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 4.62},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 4.57},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 4.43},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 4.49},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 4.57},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 5.06},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 5.08},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 4.98},
#  {'Flag and Footnotes': 'i',
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 5.57},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 5.24},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 5.47},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 5.29},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 4.92},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 4.88},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 4.7},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 4.72},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 5.61},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 6.03},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 5.66},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 5.16},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 4.29},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 4.24},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 4.27},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 4.35},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 4.66},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 4.72},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 4.73},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 4.92},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 5.67},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 6.43},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 6.41},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 6.15},
#  {'Flag and Footnotes': 'i',
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 3.71},
#  {'Flag and Footnotes': 'i',
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 3.5},
#  {'Flag and Footnotes': 'i',
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 3.57},
#  {'Flag and Footnotes': 'i',
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 3.56},
#  {'Flag and Footnotes': 'i',
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 3.83},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 4.09},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': nan},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': nan},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': nan},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': nan},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': nan},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': nan},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 4.28},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 4.24},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 4.25},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 4.28},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 4.25},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 4.23},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 4.26},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 4.34},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 4.62},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 5.02},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 4.98},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 4.82},
#  {'Flag and Footnotes': nan,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 6.04},
#  {'Flag and Footnotes': nan,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 5.95},
#  {'Flag and Footnotes': nan,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 5.9},
#  {'Flag and Footnotes': nan,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 5.92},
#  {'Flag and Footnotes': nan,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 5.8},
#  {'Flag and Footnotes': nan,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 5.67},
#  {'Flag and Footnotes': nan,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 5.61},
#  {'Flag and Footnotes': nan,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 5.62},
#  {'Flag and Footnotes': nan,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 5.62},
#  {'Flag and Footnotes': nan,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 5.9},
#  {'Flag and Footnotes': nan,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 5.86},
#  {'Flag and Footnotes': nan,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 5.68},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 4.52},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 4.83},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 4.6},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 4.72},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 4.56},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 4.41},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 4.67},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 4.27},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 4.56},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 4.7},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 4.5},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 4.29},
#  {'Flag and Footnotes': 'i',
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 5.42},
#  {'Flag and Footnotes': 'i',
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 5.98},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 6.6},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 7.37},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 6.77},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 6.95},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 7.02},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 6.95},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 7.45},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 7.98},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 7.92},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 7.87},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 5.64},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 7.22},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 6.6},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 5.58},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 5.12},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 5.14},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 5.13},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 5.07},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 5.71},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 5.59},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 4.96},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 4.96},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 5.63},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 5.86},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 5.81},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 5.14},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Lithuania',
# ...
#  {'Flag and Footnotes': nan,
#   'GEO': 'Netherlands',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 5.93},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 5.66},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 5.74},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 5.68},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 5.53},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 5.48},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 5.44},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 5.4},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 5.33},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 5.47},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 5.98},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 5.91},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 5.8},
#  {'Flag and Footnotes': 'i',
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 4.87},
#  {'Flag and Footnotes': 'i',
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 5.42},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 5.41},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 5.35},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 5.41},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 5.47},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 5.25},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 4.91},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 5.08},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 5.09},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 5.17},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 4.94},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 5.42},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 5.39},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 5.33},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 5.38},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 5.1},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 5.21},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 5.07},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 5.1},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 4.89},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 5.79},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 5.62},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 5.27},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 2.88},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 3.25},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 3.51},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 3.45},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 3.28},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 3.48},
#  {'Flag and Footnotes': 'u',
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': nan},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 4.25},
#  {'Flag and Footnotes': 'u',
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': nan},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 4.24},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 3.53},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 3.07},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': nan},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 5.86},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 5.76},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 5.8},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 5.74},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 5.73},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 5.72},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 5.15},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 5.2},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 5.69},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 5.68},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 5.68},
#  {'Flag and Footnotes': 'i',
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 3.92},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 3.99},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 4.31},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 4.3},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 4.19},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 3.85},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 3.8},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 3.62},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 3.61},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 4.09},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 4.22},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 4.06},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 5.89},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 6.06},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 6.22},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 6.43},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 6.42},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 6.3},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 6.18},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 5.9},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 6.1},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 6.81},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 6.85},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 6.76}]

# %%
#insert documents in the collection
collection.insert_many(df.to_dict("records"))

# %%
#Check that we have a non empty collection.
db.collection_names()
# Out:
# [u'edu']

# %% [markdown]
# To recap, we have databases containing collections. A collection is made up of documents. Each document is made up of fields.

# %% [markdown]
# ### Retrieving data

# %%
collection.find_one() #Returns first document in the collection
# Out:
# {u'Flag and Footnotes': nan,
#  u'GEO': u'European Union (28 countries)',
#  u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#  u'TIME': 2000,
#  u'Value': nan,
#  u'_id': ObjectId('5d8cbe268f5130f6a80fc4ba')}

# %% [markdown]
# To get more than a single document as the result of a query we use the find() method. find() returns a Cursor instance, which allows us to iterate over all matching documents.

# %%
collection.find()

# %%
[d for d in collection.find()] 
   # print (d)
# Out:
# [{u'Flag and Footnotes': nan,
#   u'GEO': u'European Union (28 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2000,
#   u'Value': nan,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4ba')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'European Union (28 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2001,
#   u'Value': nan,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4bb')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'European Union (28 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2002,
#   u'Value': 5.0,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4bc')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'European Union (28 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2003,
#   u'Value': 5.03,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4bd')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'European Union (28 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2004,
#   u'Value': 4.95,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4be')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'European Union (28 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2005,
#   u'Value': 4.92,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4bf')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'European Union (28 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2006,
#   u'Value': 4.91,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4c0')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'European Union (28 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2007,
#   u'Value': 4.92,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4c1')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'European Union (28 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2008,
#   u'Value': 5.04,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4c2')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'European Union (28 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2009,
#   u'Value': 5.38,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4c3')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'European Union (28 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2010,
#   u'Value': 5.41,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4c4')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'European Union (28 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2011,
#   u'Value': 5.25,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4c5')},
#  {u'Flag and Footnotes': u's',
#   u'GEO': u'European Union (27 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2000,
#   u'Value': 4.91,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4c6')},
#  {u'Flag and Footnotes': u's',
#   u'GEO': u'European Union (27 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2001,
#   u'Value': 4.99,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4c7')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'European Union (27 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2002,
#   u'Value': 5.0,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4c8')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'European Union (27 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2003,
#   u'Value': 5.04,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4c9')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'European Union (27 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2004,
#   u'Value': 4.95,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4ca')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'European Union (27 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2005,
#   u'Value': 4.92,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4cb')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'European Union (27 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2006,
#   u'Value': 4.91,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4cc')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'European Union (27 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2007,
#   u'Value': 4.93,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4cd')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'European Union (27 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2008,
#   u'Value': 5.04,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4ce')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'European Union (27 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2009,
#   u'Value': 5.38,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4cf')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'European Union (27 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2010,
#   u'Value': 5.41,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4d0')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'European Union (27 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2011,
#   u'Value': 5.25,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4d1')},
#  {u'Flag and Footnotes': u's',
#   u'GEO': u'European Union (25 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2000,
#   u'Value': 4.94,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4d2')},
#  {u'Flag and Footnotes': u's',
#   u'GEO': u'European Union (25 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2001,
#   u'Value': 5.02,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4d3')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'European Union (25 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2002,
#   u'Value': 5.03,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4d4')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'European Union (25 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2003,
#   u'Value': 5.06,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4d5')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'European Union (25 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2004,
#   u'Value': 4.98,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4d6')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'European Union (25 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2005,
#   u'Value': 4.95,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4d7')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'European Union (25 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2006,
#   u'Value': 4.93,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4d8')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'European Union (25 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2007,
#   u'Value': 4.95,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4d9')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'European Union (25 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2008,
#   u'Value': 5.06,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4da')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'European Union (25 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2009,
#   u'Value': 5.41,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4db')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'European Union (25 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2010,
#   u'Value': 5.46,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4dc')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'European Union (25 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2011,
#   u'Value': 5.31,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4dd')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Euro area (18 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2000,
#   u'Value': nan,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4de')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Euro area (18 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2001,
#   u'Value': nan,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4df')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (18 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2002,
#   u'Value': 4.87,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4e0')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (18 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2003,
#   u'Value': 4.89,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4e1')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (18 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2004,
#   u'Value': 4.8,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4e2')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (18 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2005,
#   u'Value': 4.72,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4e3')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (18 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2006,
#   u'Value': 4.69,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4e4')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (18 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2007,
#   u'Value': 4.79,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4e5')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (18 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2008,
#   u'Value': 4.94,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4e6')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (18 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2009,
#   u'Value': 5.31,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4e7')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (18 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2010,
#   u'Value': 5.28,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4e8')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (18 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2011,
#   u'Value': 5.15,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4e9')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Euro area (17 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2000,
#   u'Value': nan,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4ea')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Euro area (17 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2001,
#   u'Value': nan,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4eb')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (17 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2002,
#   u'Value': 4.86,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4ec')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (17 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2003,
#   u'Value': 4.89,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4ed')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (17 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2004,
#   u'Value': 4.8,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4ee')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (17 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2005,
#   u'Value': 4.72,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4ef')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (17 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2006,
#   u'Value': 4.69,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4f0')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (17 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2007,
#   u'Value': 4.79,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4f1')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (17 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2008,
#   u'Value': 4.94,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4f2')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (17 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2009,
#   u'Value': 5.31,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4f3')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (17 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2010,
#   u'Value': 5.28,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4f4')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (17 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2011,
#   u'Value': 5.15,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4f5')},
#  {u'Flag and Footnotes': u'u',
#   u'GEO': u'Euro area (15 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2000,
#   u'Value': nan,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4f6')},
#  {u'Flag and Footnotes': u's',
#   u'GEO': u'Euro area (15 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2001,
#   u'Value': 4.98,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4f7')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (15 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2002,
#   u'Value': 5.01,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4f8')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (15 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2003,
#   u'Value': 5.04,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4f9')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (15 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2004,
#   u'Value': 4.96,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4fa')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (15 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2005,
#   u'Value': 4.89,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4fb')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (15 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2006,
#   u'Value': 4.87,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4fc')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (15 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2007,
#   u'Value': 4.81,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4fd')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (15 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2008,
#   u'Value': 4.95,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4fe')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (15 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2009,
#   u'Value': 5.32,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc4ff')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (15 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2010,
#   u'Value': 5.29,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc500')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (15 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2011,
#   u'Value': 5.16,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc501')},
#  {u'Flag and Footnotes': u'u',
#   u'GEO': u'Euro area (13 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2000,
#   u'Value': nan,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc502')},
#  {u'Flag and Footnotes': u's',
#   u'GEO': u'Euro area (13 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2001,
#   u'Value': 4.97,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc503')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (13 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2002,
#   u'Value': 5.0,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc504')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (13 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2003,
#   u'Value': 5.04,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc505')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (13 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2004,
#   u'Value': 4.95,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc506')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (13 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2005,
#   u'Value': 4.89,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc507')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (13 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2006,
#   u'Value': 4.87,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc508')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (13 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2007,
#   u'Value': 4.8,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc509')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (13 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2008,
#   u'Value': 4.94,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc50a')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (13 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2009,
#   u'Value': 5.32,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc50b')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (13 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2010,
#   u'Value': 5.28,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc50c')},
#  {u'Flag and Footnotes': u'e',
#   u'GEO': u'Euro area (13 countries)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2011,
#   u'Value': 5.15,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc50d')},
#  {u'Flag and Footnotes': u'u',
#   u'GEO': u'Belgium',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2000,
#   u'Value': nan,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc50e')},
#  {u'Flag and Footnotes': u'i',
#   u'GEO': u'Belgium',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2001,
#   u'Value': 5.99,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc50f')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Belgium',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2002,
#   u'Value': 6.09,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc510')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Belgium',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2003,
#   u'Value': 6.02,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc511')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Belgium',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2004,
#   u'Value': 5.95,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc512')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Belgium',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2005,
#   u'Value': 5.92,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc513')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Belgium',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2006,
#   u'Value': 5.98,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc514')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Belgium',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2007,
#   u'Value': 6.0,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc515')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Belgium',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2008,
#   u'Value': 6.43,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc516')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Belgium',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2009,
#   u'Value': 6.57,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc517')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Belgium',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2010,
#   u'Value': 6.58,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc518')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Belgium',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2011,
#   u'Value': 6.55,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc519')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Bulgaria',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2000,
#   u'Value': 3.88,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc51a')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Bulgaria',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2001,
#   u'Value': 3.7,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc51b')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Bulgaria',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2002,
#   u'Value': 3.94,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc51c')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Bulgaria',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2003,
#   u'Value': 4.09,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc51d')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Bulgaria',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2004,
#   u'Value': 4.4,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc51e')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Bulgaria',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2005,
#   u'Value': 4.25,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc51f')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Bulgaria',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2006,
#   u'Value': 4.04,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc520')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Bulgaria',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2007,
#   u'Value': 3.88,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc521')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Bulgaria',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2008,
#   u'Value': 4.44,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc522')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Bulgaria',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2009,
#   u'Value': 4.58,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc523')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Bulgaria',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2010,
#   u'Value': 4.1,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc524')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Bulgaria',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2011,
#   u'Value': 3.82,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc525')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Czech Republic',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2000,
#   u'Value': 3.83,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc526')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Czech Republic',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2001,
#   u'Value': 3.93,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc527')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Czech Republic',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2002,
#   u'Value': 4.15,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc528')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Czech Republic',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2003,
#   u'Value': 4.32,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc529')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Czech Republic',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2004,
#   u'Value': 4.2,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc52a')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Czech Republic',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2005,
#   u'Value': 4.08,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc52b')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Czech Republic',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2006,
#   u'Value': 4.42,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc52c')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Czech Republic',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2007,
#   u'Value': 4.05,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc52d')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Czech Republic',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2008,
#   u'Value': 3.92,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc52e')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Czech Republic',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2009,
#   u'Value': 4.36,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc52f')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Czech Republic',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2010,
#   u'Value': 4.25,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc530')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Czech Republic',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2011,
#   u'Value': 4.51,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc531')},
#  {u'Flag and Footnotes': u'i',
#   u'GEO': u'Denmark',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2000,
#   u'Value': 8.28,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc532')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Denmark',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2001,
#   u'Value': 8.44,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc533')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Denmark',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2002,
#   u'Value': 8.44,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc534')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Denmark',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2003,
#   u'Value': 8.33,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc535')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Denmark',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2004,
#   u'Value': 8.43,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc536')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Denmark',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2005,
#   u'Value': 8.3,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc537')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Denmark',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2006,
#   u'Value': 7.97,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc538')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Denmark',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2007,
#   u'Value': 7.81,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc539')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Denmark',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2008,
#   u'Value': 7.68,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc53a')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Denmark',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2009,
#   u'Value': 8.74,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc53b')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Denmark',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2010,
#   u'Value': 8.81,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc53c')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Denmark',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2011,
#   u'Value': 8.75,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc53d')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Germany (until 1990 former territory of the FRG)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2000,
#   u'Value': 4.45,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc53e')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Germany (until 1990 former territory of the FRG)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2001,
#   u'Value': 4.51,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc53f')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Germany (until 1990 former territory of the FRG)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2002,
#   u'Value': 4.72,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc540')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Germany (until 1990 former territory of the FRG)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2003,
#   u'Value': 4.74,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc541')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Germany (until 1990 former territory of the FRG)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2004,
#   u'Value': 4.62,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc542')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Germany (until 1990 former territory of the FRG)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2005,
#   u'Value': 4.57,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc543')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Germany (until 1990 former territory of the FRG)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2006,
#   u'Value': 4.43,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc544')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Germany (until 1990 former territory of the FRG)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2007,
#   u'Value': 4.49,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc545')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Germany (until 1990 former territory of the FRG)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2008,
#   u'Value': 4.57,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc546')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Germany (until 1990 former territory of the FRG)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2009,
#   u'Value': 5.06,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc547')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Germany (until 1990 former territory of the FRG)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2010,
#   u'Value': 5.08,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc548')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Germany (until 1990 former territory of the FRG)',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2011,
#   u'Value': 4.98,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc549')},
#  {u'Flag and Footnotes': u'i',
#   u'GEO': u'Estonia',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2000,
#   u'Value': 5.57,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc54a')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Estonia',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2001,
#   u'Value': 5.24,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc54b')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Estonia',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2002,
#   u'Value': 5.47,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc54c')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Estonia',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2003,
#   u'Value': 5.29,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc54d')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Estonia',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2004,
#   u'Value': 4.92,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc54e')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Estonia',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2005,
#   u'Value': 4.88,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc54f')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Estonia',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2006,
#   u'Value': 4.7,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc550')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Estonia',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2007,
#   u'Value': 4.72,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc551')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Estonia',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2008,
#   u'Value': 5.61,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc552')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Estonia',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2009,
#   u'Value': 6.03,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc553')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Estonia',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2010,
#   u'Value': 5.66,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc554')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Estonia',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2011,
#   u'Value': 5.16,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc555')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Ireland',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2000,
#   u'Value': 4.29,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc556')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Ireland',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2001,
#   u'Value': 4.24,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc557')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Ireland',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2002,
#   u'Value': 4.27,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc558')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Ireland',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2003,
#   u'Value': 4.35,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc559')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Ireland',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2004,
#   u'Value': 4.66,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc55a')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Ireland',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2005,
#   u'Value': 4.72,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc55b')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Ireland',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2006,
#   u'Value': 4.73,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc55c')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Ireland',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2007,
#   u'Value': 4.92,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc55d')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Ireland',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2008,
#   u'Value': 5.67,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc55e')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Ireland',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2009,
#   u'Value': 6.43,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc55f')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Ireland',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2010,
#   u'Value': 6.41,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc560')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Ireland',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2011,
#   u'Value': 6.15,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc561')},
#  {u'Flag and Footnotes': u'i',
#   u'GEO': u'Greece',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2000,
#   u'Value': 3.71,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc562')},
#  {u'Flag and Footnotes': u'i',
#   u'GEO': u'Greece',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2001,
#   u'Value': 3.5,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc563')},
#  {u'Flag and Footnotes': u'i',
#   u'GEO': u'Greece',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2002,
#   u'Value': 3.57,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc564')},
#  {u'Flag and Footnotes': u'i',
#   u'GEO': u'Greece',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2003,
#   u'Value': 3.56,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc565')},
#  {u'Flag and Footnotes': u'i',
#   u'GEO': u'Greece',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2004,
#   u'Value': 3.83,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc566')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Greece',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2005,
#   u'Value': 4.09,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc567')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Greece',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2006,
#   u'Value': nan,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc568')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Greece',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2007,
#   u'Value': nan,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc569')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Greece',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2008,
#   u'Value': nan,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc56a')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Greece',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2009,
#   u'Value': nan,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc56b')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Greece',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2010,
#   u'Value': nan,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc56c')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Greece',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2011,
#   u'Value': nan,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc56d')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Spain',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2000,
#   u'Value': 4.28,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc56e')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Spain',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2001,
#   u'Value': 4.24,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc56f')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Spain',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2002,
#   u'Value': 4.25,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc570')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Spain',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2003,
#   u'Value': 4.28,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc571')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Spain',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2004,
#   u'Value': 4.25,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc572')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Spain',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2005,
#   u'Value': 4.23,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc573')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Spain',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2006,
#   u'Value': 4.26,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc574')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Spain',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2007,
#   u'Value': 4.34,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc575')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Spain',
# ...
#   u'TIME': 2006,
#   u'Value': 5.25,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc5f8')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Poland',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2007,
#   u'Value': 4.91,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc5f9')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Poland',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2008,
#   u'Value': 5.08,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc5fa')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Poland',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2009,
#   u'Value': 5.09,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc5fb')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Poland',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2010,
#   u'Value': 5.17,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc5fc')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Poland',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2011,
#   u'Value': 4.94,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc5fd')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Portugal',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2000,
#   u'Value': 5.42,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc5fe')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Portugal',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2001,
#   u'Value': 5.39,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc5ff')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Portugal',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2002,
#   u'Value': 5.33,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc600')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Portugal',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2003,
#   u'Value': 5.38,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc601')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Portugal',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2004,
#   u'Value': 5.1,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc602')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Portugal',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2005,
#   u'Value': 5.21,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc603')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Portugal',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2006,
#   u'Value': 5.07,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc604')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Portugal',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2007,
#   u'Value': 5.1,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc605')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Portugal',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2008,
#   u'Value': 4.89,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc606')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Portugal',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2009,
#   u'Value': 5.79,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc607')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Portugal',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2010,
#   u'Value': 5.62,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc608')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Portugal',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2011,
#   u'Value': 5.27,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc609')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Romania',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2000,
#   u'Value': 2.88,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc60a')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Romania',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2001,
#   u'Value': 3.25,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc60b')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Romania',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2002,
#   u'Value': 3.51,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc60c')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Romania',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2003,
#   u'Value': 3.45,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc60d')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Romania',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2004,
#   u'Value': 3.28,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc60e')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Romania',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2005,
#   u'Value': 3.48,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc60f')},
#  {u'Flag and Footnotes': u'u',
#   u'GEO': u'Romania',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2006,
#   u'Value': nan,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc610')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Romania',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2007,
#   u'Value': 4.25,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc611')},
#  {u'Flag and Footnotes': u'u',
#   u'GEO': u'Romania',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2008,
#   u'Value': nan,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc612')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Romania',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2009,
#   u'Value': 4.24,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc613')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Romania',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2010,
#   u'Value': 3.53,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc614')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Romania',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2011,
#   u'Value': 3.07,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc615')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Slovenia',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2000,
#   u'Value': nan,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc616')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Slovenia',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2001,
#   u'Value': 5.86,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc617')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Slovenia',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2002,
#   u'Value': 5.76,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc618')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Slovenia',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2003,
#   u'Value': 5.8,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc619')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Slovenia',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2004,
#   u'Value': 5.74,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc61a')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Slovenia',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2005,
#   u'Value': 5.73,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc61b')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Slovenia',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2006,
#   u'Value': 5.72,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc61c')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Slovenia',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2007,
#   u'Value': 5.15,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc61d')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Slovenia',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2008,
#   u'Value': 5.2,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc61e')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Slovenia',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2009,
#   u'Value': 5.69,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc61f')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Slovenia',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2010,
#   u'Value': 5.68,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc620')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Slovenia',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2011,
#   u'Value': 5.68,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc621')},
#  {u'Flag and Footnotes': u'i',
#   u'GEO': u'Slovakia',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2000,
#   u'Value': 3.92,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc622')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Slovakia',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2001,
#   u'Value': 3.99,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc623')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Slovakia',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2002,
#   u'Value': 4.31,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc624')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Slovakia',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2003,
#   u'Value': 4.3,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc625')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Slovakia',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2004,
#   u'Value': 4.19,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc626')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Slovakia',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2005,
#   u'Value': 3.85,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc627')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Slovakia',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2006,
#   u'Value': 3.8,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc628')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Slovakia',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2007,
#   u'Value': 3.62,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc629')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Slovakia',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2008,
#   u'Value': 3.61,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc62a')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Slovakia',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2009,
#   u'Value': 4.09,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc62b')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Slovakia',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2010,
#   u'Value': 4.22,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc62c')},
#  {u'Flag and Footnotes': u'd',
#   u'GEO': u'Slovakia',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2011,
#   u'Value': 4.06,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc62d')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Finland',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2000,
#   u'Value': 5.89,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc62e')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Finland',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2001,
#   u'Value': 6.06,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc62f')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Finland',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2002,
#   u'Value': 6.22,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc630')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Finland',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2003,
#   u'Value': 6.43,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc631')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Finland',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2004,
#   u'Value': 6.42,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc632')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Finland',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2005,
#   u'Value': 6.3,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc633')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Finland',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2006,
#   u'Value': 6.18,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc634')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Finland',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2007,
#   u'Value': 5.9,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc635')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Finland',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2008,
#   u'Value': 6.1,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc636')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Finland',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2009,
#   u'Value': 6.81,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc637')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Finland',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2010,
#   u'Value': 6.85,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc638')},
#  {u'Flag and Footnotes': nan,
#   u'GEO': u'Finland',
#   u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#   u'TIME': 2011,
#   u'Value': 6.76,
#   u'_id': ObjectId('5d8cbe268f5130f6a80fc639')}]

# %% [markdown]
# If we just want to know how many documents match a query we can perform a count() operation instead of a full query. We can get a count of all of the documents in a collection:

# %%
collection.count()
# Out:
# 384

# %% [markdown]
# ### Basic queries

# %% [markdown]
# Querying in pymongo uses .find()

# %%
collection.find({"TIME":2009}).count()
# Out:
# 32

# %%
collection.find({"GEO":"Spain"}).count()
# Out:
# 12

# %% [markdown]
# Observe that it finds exact matches (including type)

# %%
collection.find({"TIME":"2009"}).count()
# Out:
# 0

# %%
collection.find({"GEO":"SPAIN"}).count()
# Out:
# 0

# %% [markdown]
# Operations include *gt* (greater than), *gte* (greater than equal), *lt* (lesser than), *lte* (lesser than equal), *ne* (not equal), *nin* (not in a list), *regex* (regular expression), *exists*, *not*, *or*, *and*, etc. Let us see some examples:

# %%
collection.find({"TIME":{"$gte":2009}}).count()
# Out:
# 96

# %%
substring = r'Euro'
reg = substring
[(i["GEO"]) for i in collection.find({"GEO":{"$regex":reg}})]
# Out:
# [u'European Union (28 countries)',
#  u'European Union (28 countries)',
#  u'European Union (28 countries)',
#  u'European Union (28 countries)',
#  u'European Union (28 countries)',
#  u'European Union (28 countries)',
#  u'European Union (28 countries)',
#  u'European Union (28 countries)',
#  u'European Union (28 countries)',
#  u'European Union (28 countries)',
#  u'European Union (28 countries)',
#  u'European Union (28 countries)',
#  u'European Union (27 countries)',
#  u'European Union (27 countries)',
#  u'European Union (27 countries)',
#  u'European Union (27 countries)',
#  u'European Union (27 countries)',
#  u'European Union (27 countries)',
#  u'European Union (27 countries)',
#  u'European Union (27 countries)',
#  u'European Union (27 countries)',
#  u'European Union (27 countries)',
#  u'European Union (27 countries)',
#  u'European Union (27 countries)',
#  u'European Union (25 countries)',
#  u'European Union (25 countries)',
#  u'European Union (25 countries)',
#  u'European Union (25 countries)',
#  u'European Union (25 countries)',
#  u'European Union (25 countries)',
#  u'European Union (25 countries)',
#  u'European Union (25 countries)',
#  u'European Union (25 countries)',
#  u'European Union (25 countries)',
#  u'European Union (25 countries)',
#  u'European Union (25 countries)',
#  u'Euro area (18 countries)',
#  u'Euro area (18 countries)',
#  u'Euro area (18 countries)',
#  u'Euro area (18 countries)',
#  u'Euro area (18 countries)',
#  u'Euro area (18 countries)',
#  u'Euro area (18 countries)',
#  u'Euro area (18 countries)',
#  u'Euro area (18 countries)',
#  u'Euro area (18 countries)',
#  u'Euro area (18 countries)',
#  u'Euro area (18 countries)',
#  u'Euro area (17 countries)',
#  u'Euro area (17 countries)',
#  u'Euro area (17 countries)',
#  u'Euro area (17 countries)',
#  u'Euro area (17 countries)',
#  u'Euro area (17 countries)',
#  u'Euro area (17 countries)',
#  u'Euro area (17 countries)',
#  u'Euro area (17 countries)',
#  u'Euro area (17 countries)',
#  u'Euro area (17 countries)',
#  u'Euro area (17 countries)',
#  u'Euro area (15 countries)',
#  u'Euro area (15 countries)',
#  u'Euro area (15 countries)',
#  u'Euro area (15 countries)',
#  u'Euro area (15 countries)',
#  u'Euro area (15 countries)',
#  u'Euro area (15 countries)',
#  u'Euro area (15 countries)',
#  u'Euro area (15 countries)',
#  u'Euro area (15 countries)',
#  u'Euro area (15 countries)',
#  u'Euro area (15 countries)',
#  u'Euro area (13 countries)',
#  u'Euro area (13 countries)',
#  u'Euro area (13 countries)',
#  u'Euro area (13 countries)',
#  u'Euro area (13 countries)',
#  u'Euro area (13 countries)',
#  u'Euro area (13 countries)',
#  u'Euro area (13 countries)',
#  u'Euro area (13 countries)',
#  u'Euro area (13 countries)',
#  u'Euro area (13 countries)',
#  u'Euro area (13 countries)']

# %%
for item in collection.find({"GEO":{"$regex":reg}}):
     print (item['GEO'])
# Out:
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)

# %% [markdown]
# ### Update

# %% [markdown]
# In this section, several methods for updating and deleting documents are reveiwed:
#
# + Update. This method finds the documents defined by query and **replaces** it by the new document.

# %%
#Insert One new Document
import numpy as np
doc = {'Flag and Footnotes': np.nan,
  'GEO': 'Catalunya',
  'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
  'TIME': 2017,
  'Value': np.nan}
collection.insert_one(doc)

# %%
for doc in collection.find({'GEO':"Catalunya"}):
    print (doc)
# Out:
# {u'Value': nan, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2017, u'Flag and Footnotes': nan, u'_id': ObjectId('5d8cc0f28f5130f6a80fc63a'), u'GEO': u'Catalunya'}

# %%
#Replace first occurence
newdoc = {'Flag and Footnotes': np.nan,
  'GEO': 'Catalunya',
  'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
  'TIME': 2017,
  'Value': 15}
collection.replace_one({'GEO':"Catalunya"},newdoc)

for doc in collection.find({'GEO':"Catalunya"}):
    print (doc)
# Out:
# {u'Value': 15, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2017, u'Flag and Footnotes': nan, u'_id': ObjectId('5d8cc0f28f5130f6a80fc63a'), u'GEO': u'Catalunya'}

# %% [markdown]
# If we don't want to write again all the document and just put the field that we want to change then we have to use update_one and adding a sub-command.  Let us check some of them:

# %% [markdown]
# + Sub-command **Set**:
#
# This statement updates in the document in collection where field matches value1 by replacing the value of the field field1 with value2. This operator will add the specified field or fields if they do not exist in this document or replace the existing value of the specified field(s) if they already exist.
#
# An upsert eliminates the need to perform a separate database call to check for the existence of a record before performing either an update or an insert operation. Typically update operations update existing documents, but in MongoDB, the update_one() operation can accept an upsert option as an argument. Upserts are a hybrid operation that use the query argument to determine the write operation:
#
# If the query matches an existing document(s), the upsert performs an update.
# If the query matches no document in the collection, the upsert inserts a single document.

# %%
#Update first occurrence
collection.update_one({'GEO':"Catalunya"},{"$set":{"Value":12}})

# %%
for doc in collection.find({'GEO':"Catalunya"}):
    print (doc)
# Out:
# {u'Value': 12, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2017, u'Flag and Footnotes': nan, u'_id': ObjectId('5d8cc0f28f5130f6a80fc63a'), u'GEO': u'Catalunya'}

# %% [markdown]
# By default, if the filter doesn't return any document, nothing is inserted to database. If you want to insert it, then set the upsert flag to `True`

# %%
collection.update_one({'GEO':"Andorra"},{"$set":{"Value":12}},upsert = True)
for doc in collection.find({'GEO':"Andorra"}):
    print (doc)
# Out:
# {u'_id': ObjectId('5d8cc1b663243ebd656dec5c'), u'GEO': u'Andorra', u'Value': 12}

# %% [markdown]
# + Sub-commnad **Unset**:
#
# The unset operator deletes a particular field. If documents match the initial query but do not have the field specified in the unset operation, there the statement has no effect on the document.

# %%
collection.update_one({'GEO':"Catalunya"},{"$unset":{"Flag and Footnotes":""}})

# %%
for doc in collection.find({'GEO':"Catalunya"}):
    print (doc)
# Out:
# {u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'_id': ObjectId('5d8cc0f28f5130f6a80fc63a'), u'GEO': u'Catalunya', u'Value': 12, u'TIME': 2017}

# %% [markdown]
# ### Delete operations

# %% [markdown]
# We can remove elements by simply:

# %%
collection.delete_one({"GEO":"Andorra"})

# %%
for doc in collection.find({"GEO":"Andorra"}):
    print (doc)

# %% [markdown]
# And remove a collection by:

# %%
db.collection_names()
# Out:
# [u'edu']

# %%
db.drop_collection("edu")
db.collection_names()
# Out:
# []

# %% [markdown]
# And remove a database by:

# %%
conn.database_names()
# Out:
# [u'TripAdvisor',
#  u'admin',
#  u'config',
#  u'db_enquestes',
#  u'foodb',
#  u'local',
#  u'twitter']

# %%
conn.drop_database('ads')
conn.database_names()
# Out:
# [u'TripAdvisor',
#  u'admin',
#  u'config',
#  u'db_enquestes',
#  u'foodb',
#  u'local',
#  u'twitter']

# %% [markdown]
# And finally close the connection with the database.

# %%
conn.close()

# %% [markdown]
# ## Connecting with a MongoDB on the cloud
#
# + First, create an account in [https://cloud.mongodb.com/](https://cloud.mongodb.com/)
# + Build a free cluster instance of 0,5Gb
# + Create a Dabase User under Database Access, and connect to it following next code

# %%
import pymongo
try:
    #create a credentials.txt file in this folder:
    #first line: Database username (not account username)
    #second line: Database username password (not account password)
    #third line: Databse url with port (you can find it in the cloud dashboard)
  

    with open("credentials.txt", 'r') as f:
        [name,password,url,dbname]=f.read().splitlines()
    conn=pymongo.MongoClient("mongodb+srv://{}:{}@{}".format(name,password,url))
    print ("Connected successfully!!!")
    
except pymongo.errors.ConnectionFailure as e:
    print ("Could not connect to MongoDB: %s" % e) 
conn
# Out:
# Connected successfully!!!
# MongoClient(host=['cluster0-shard-00-00-jev3w.mongodb.net:27017', 'cluster0-shard-00-01-jev3w.mongodb.net:27017', 'cluster0-shard-00-02-jev3w.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, replicaset=u'Cluster0-shard-0', ssl=True, retrywrites=True, w='majority', authsource=u'admin')

# %%
import pandas as pd

df = pd.read_csv('./educ_figdp_1_Data.csv',na_values=':')
#Create a database using db = conn.name_db or dictionary access db = conn['name_db']
db = conn['ads']
print (db)
collection = db.edu
collection.insert_many(df.to_dict("records"))
db.list_collection_names()
# Out:
# Database(MongoClient(host=['cluster0-shard-00-00-jev3w.mongodb.net:27017', 'cluster0-shard-00-01-jev3w.mongodb.net:27017', 'cluster0-shard-00-02-jev3w.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, replicaset=u'Cluster0-shard-0', ssl=True, retrywrites=True, w='majority', authsource=u'admin'), u'ads')
# [u'edu']

# %% [markdown]
# You can check your mongoDB database in this website:
# [https://cloud.mongodb.com/](https://cloud.mongodb.com/)

# %%
db.drop_collection("edu")
conn.close()
