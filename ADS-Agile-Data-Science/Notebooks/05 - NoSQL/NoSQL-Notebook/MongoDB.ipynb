# %%
from IPython.core.display import HTML
def css_styling():   
    styles = open("styles/custom.css", "r").read() 
    return HTML(styles)

# %% [markdown]
# # 1 Introduction to MongoDB
# <small>This introduction is partially inspired on the notes of Alberto Negron's [blog](http://altons.github.io/python/2013/01/21/gentle-introduction-to-mongodb-using-pymongo/)</small>

# %% [markdown]
# MongoDB is a document-oriented database, part of the NoSQL family of database systems. MongoDB stores structured data as JSON-like structures. From a pythonic point of view it is like storing dictionary data structures. One of its main feature is its schema-less feature, i.e. it supports dynamic schemas. A schema in a relational database informally refer to the structure of the data it stores, i.e. what kind of data, which tables, which relations, etc.

# %% [markdown]
# ## Connecting with a MongoDB on the cloud
#
# + First, create an account in [https://cloud.mongodb.com/](https://cloud.mongodb.com/)
# + Build a free cluster instance of 0,5Gb
# + Create a Dabase User under Database Access, and connect to it following next code
# + Install pymongo + dnspython
#
# `pip install "pymongo[srv]"`

# %%
# !pip install pymongo[srv]
# Out:
# Requirement already satisfied: pymongo[srv] in c:\anaconda3\lib\site-packages (3.12.0)
# Requirement already satisfied: dnspython<2.0.0,>=1.16.0 in c:\anaconda3\lib\site-packages (from pymongo[srv]) (1.16.0)

# %%
import pymongo
try:
    #create a credentials.txt file in this folder:
    #first line: Database username (not account username)
    #second line: Database username password (not account password)
    #third line: Databse url with port (you can find it in the cloud dashboard)
    #fourth lin: Database name
    if 'conn' in globals():
        conn.close()
        print("Closing")
    
    with open("credentials.txt", 'r') as f:
        [name,password,url,dbname]=f.read().splitlines()
    print(name, password, url, dbname)
    conn=pymongo.MongoClient("mongodb+srv://{}:{}@{}".format(name,password,url))
    print ("Connected successfully!!!")
    
except pymongo.errors.ConnectionFailure as e:
    print ("Could not connect to MongoDB: %s" % e) 
conn
db = conn[dbname]
db
# Out:
# Closing
# adsadmin adsadmin ads.trb7f.mongodb.net/ads?retryWrites=true&w=majority ads
# Connected successfully!!!
# Database(MongoClient(host=['ads-shard-00-02.trb7f.mongodb.net:27017', 'ads-shard-00-01.trb7f.mongodb.net:27017', 'ads-shard-00-00.trb7f.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-r513ol-shard-0', ssl=True), 'ads')

# %% [markdown]
# You can check your mongoDB database in this website:
# [https://cloud.mongodb.com/](https://cloud.mongodb.com/)

# %% [markdown]
# ### Connecting with a MongoDB database in localhost

# %% [markdown]
# First of all let us configure the MongoDB system.
#
# + Download mongoDB.
#
# https://www.mongodb.com/download-center/community
#
# + Create data directory:
#
# `sudo mkdir -p /data/db`
# + Check that the server works
#
# `sudo ./mongod --nojournal &`
#
# + Check the connection to the server:
#
# in another terminal write `mongo` , check that it does not raise any error and exit the console.
# + Close the mongo daemon (mongod).
#         You may have to kill mongod with
#
# `killall mongod`
#
#         and remove the lock on the daemon,
# `rm /data/db/mongod.lock`
#
# + Let us configure a little the data base by configuring the path of the data storage and log files. Create a [mongo.conf](./mongo.conf) file such as the one provided  and start the server using the following command:
#
# `mongod --config=./mongo.conf --nojournal &`
#
# + Install pymongo
#
# `pip install pymongo`

# %%
import pymongo

# Connection to Mongo DB
try:
    conn=pymongo.MongoClient()
    print ("Connected successfully!!!")
except pymongo.errors.ConnectionFailure as e:
    print ("Could not connect to MongoDB: %s" % e) 
conn
# Out:
# Connected successfully!!!
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %% [markdown]
# ## Accessing to / Creating database
#
# We can **create** or **access to** a database using attribute access <span style = "font-family:Courier;"> db = conn.name_db</span> or dictionary acces <span style = "font-family:Courier;"> db = conn[name_db]</span>.

# %%
#Create a database using db = conn.name_db or dictionary access db = conn['name_db']
db = conn['ads']
print (db)
conn.list_database_names()
#Empty databases do not show!
# Out:
# Database(MongoClient(host=['ads-shard-00-02.trb7f.mongodb.net:27017', 'ads-shard-00-01.trb7f.mongodb.net:27017', 'ads-shard-00-00.trb7f.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-r513ol-shard-0', ssl=True), 'ads')
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-5-16b557c23d07> in <module>
#       2 db = conn['ads']
#       3 print (db)
# ----> 4 conn.list_database_names()
#       5 #Empty databases do not show!
#
# C:\anaconda3\lib\site-packages\pymongo\mongo_client.py in list_database_names(self, session)
#    2035         """
#    2036         return [doc["name"]
# -> 2037                 for doc in self.list_databases(session, nameOnly=True)]
#    2038
#    2039     def database_names(self, session=None):
#
# C:\anaconda3\lib\site-packages\pymongo\mongo_client.py in list_databases(self, session, **kwargs)
#    2016         cmd.update(kwargs)
#    2017         admin = self._database_default_options("admin")
# -> 2018         res = admin._retryable_read_command(cmd, session=session)
#    2019         # listDatabases doesn't return a cursor (yet). Fake one.
#    2020         cursor = {
#
# C:\anaconda3\lib\site-packages\pymongo\database.py in _retryable_read_command(self, command, value, check, allowable_errors, read_preference, codec_options, session, **kwargs)
#     768                                  codec_options, session=session, **kwargs)
#     769
# --> 770         return self.__client._retryable_read(
#     771             _cmd, read_preference, session)
#     772
#
# C:\anaconda3\lib\site-packages\pymongo\mongo_client.py in _retryable_read(self, func, read_pref, session, address, retryable)
#    1512         while True:
#    1513             try:
# -> 1514                 server = self._select_server(
#    1515                     read_pref, session, address=address)
#    1516                 if not server.description.retryable_reads_supported:
#
# C:\anaconda3\lib\site-packages\pymongo\mongo_client.py in _select_server(self, server_selector, session, address)
#    1344                                         % address)
#    1345             else:
# -> 1346                 server = topology.select_server(server_selector)
#    1347             return server
#    1348         except PyMongoError as exc:
#
# C:\anaconda3\lib\site-packages\pymongo\topology.py in select_server(self, selector, server_selection_timeout, address)
#     242                       address=None):
#     243         """Like select_servers, but choose a random server if several match."""
# --> 244         return random.choice(self.select_servers(selector,
#     245                                                  server_selection_timeout,
#     246                                                  address))
#
# C:\anaconda3\lib\site-packages\pymongo\topology.py in select_servers(self, selector, server_selection_timeout, address)
#     200
#     201         with self._lock:
# --> 202             server_descriptions = self._select_servers_loop(
#     203                 selector, server_timeout, address)
#     204
#
# C:\anaconda3\lib\site-packages\pymongo\topology.py in _select_servers_loop(self, selector, timeout, address)
#     216             # No suitable servers.
#     217             if timeout == 0 or now > end_time:
# --> 218                 raise ServerSelectionTimeoutError(
#     219                     "%s, Timeout: %ss, Topology Description: %r" %
#     220                     (self._error_message(selector), timeout, self.description))
#
# ServerSelectionTimeoutError: ads-shard-00-02.trb7f.mongodb.net:27017: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1125),ads-shard-00-01.trb7f.mongodb.net:27017: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1125),ads-shard-00-00.trb7f.mongodb.net:27017: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1125), Timeout: 30s, Topology Description: <TopologyDescription id: 6156232ba28373ca690e4c4d, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('ads-shard-00-00.trb7f.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('ads-shard-00-00.trb7f.mongodb.net:27017: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1125)')>, <ServerDescription ('ads-shard-00-01.trb7f.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('ads-shard-00-01.trb7f.mongodb.net:27017: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1125)')>, <ServerDescription ('ads-shard-00-02.trb7f.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('ads-shard-00-02.trb7f.mongodb.net:27017: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1125)')>]>

# %% [markdown]
# A database stores a **collection**. A collection is a group of documents stored in MongoDB, and can be thought of as the equivalent of a table in a relational database. Getting a collection in PyMongo works the same as getting a database:

# %%
collection = db.edu
db.list_collection_names()
#Empty collections do not show!
# Out:
# []

# %% [markdown]
# MongoDB stores structured data as JSON-like documents, using dynamic schemas (called BSON), rather than predefined schemas. An element of data is called a document, and documents are stored in collections. One collection may have any number of documents.
#
# Compared to relational databases, we could say collections are like tables, and documents are like records. But there is one big difference: every record in a table has the same fields (with, usually, differing values) in the same order, while each document in a collection can have completely different fields from the other documents.
#
# All you really need to know when you're using Python, however, is that documents are Python dictionaries that can have strings as keys and can contain various primitive types (int, float,unicode, datetime) as well as other documents (Python dicts) and arrays (Python lists).
#
# To insert some data into MongoDB, all we need to do is create a dict and call .insert() on the collection object. Let us exemplify this process by getting some DatFrame and storing it in the collection.

# %%
import pandas as pd
df = pd.read_csv('./educ_figdp_1_Data.csv',na_values=':')
df.head(5)
# Out:
#    TIME                            GEO  \
# 0  2000  European Union (28 countries)
# 1  2001  European Union (28 countries)
# 2  2002  European Union (28 countries)
# 3  2003  European Union (28 countries)
# 4  2004  European Union (28 countries)
#
#                                             INDIC_ED  Value Flag and Footnotes
# 0  Total public expenditure on education as % of ...    NaN                NaN
# 1  Total public expenditure on education as % of ...    NaN                NaN
# 2  Total public expenditure on education as % of ...   5.00                  e
# 3  Total public expenditure on education as % of ...   5.03                  e
# 4  Total public expenditure on education as % of ...   4.95                  e

# %%
df.to_dict("records")
# Out:
# [{'TIME': 2000,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.0,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2003,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.03,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2004,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2005,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.92,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2006,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.91,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2007,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.92,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2008,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.04,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2009,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2010,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2011,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.25,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2000,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.91,
#   'Flag and Footnotes': 's'},
#  {'TIME': 2001,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.99,
#   'Flag and Footnotes': 's'},
#  {'TIME': 2002,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.0,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2003,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.04,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2004,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2005,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.92,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2006,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.91,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2007,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.93,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2008,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.04,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2009,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2010,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2011,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.25,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2000,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': 's'},
#  {'TIME': 2001,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': 's'},
#  {'TIME': 2002,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.03,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2003,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.06,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2004,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2005,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2006,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.93,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2007,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2008,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.06,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2009,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2010,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.46,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2011,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2000,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.87,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2003,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.89,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2004,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.8,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2005,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2006,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.69,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2007,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.79,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2008,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2009,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2010,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.28,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2011,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2000,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.86,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2003,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.89,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2004,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.8,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2005,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2006,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.69,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2007,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.79,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2008,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2009,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2010,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.28,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2011,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2000,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': 'u'},
#  {'TIME': 2001,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': 's'},
#  {'TIME': 2002,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.01,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2003,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.04,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2004,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.96,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2005,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.89,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2006,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.87,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2007,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.81,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2008,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2009,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2010,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.29,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2011,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.16,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2000,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': 'u'},
#  {'TIME': 2001,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.97,
#   'Flag and Footnotes': 's'},
#  {'TIME': 2002,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.0,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2003,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.04,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2004,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2005,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.89,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2006,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.87,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2007,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.8,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2008,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2009,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2010,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.28,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2011,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2000,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': 'u'},
#  {'TIME': 2001,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.99,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2002,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.09,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2003,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.02,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2004,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.95,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2005,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.92,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2006,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.98,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2007,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.0,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2008,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.43,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2009,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.57,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2010,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.58,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2011,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.55,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2000,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.88,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.7,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.94,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.09,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.4,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.04,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.88,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.44,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.58,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.1,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.82,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.83,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.93,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.15,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.32,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.2,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.08,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.42,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.05,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.92,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.36,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.51,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.28,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2001,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.44,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2002,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.44,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2003,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.33,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.43,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.3,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2006,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.97,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2007,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.81,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2008,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.68,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2009,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.74,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2010,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.81,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2011,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.75,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2000,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.45,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.51,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.74,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.62,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.57,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.43,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.49,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.57,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.06,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.08,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.57,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2001,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.24,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.47,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.29,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.92,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.88,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.7,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2008,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.61,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.03,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.66,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.16,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.29,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.27,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.35,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.66,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.73,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.92,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.67,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.43,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.41,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.15,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.71,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2001,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.5,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2002,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.57,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2003,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.56,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2004,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.83,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2005,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.09,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.28,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.28,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.23,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.26,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.34,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.62,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.82,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.04,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.95,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.9,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.92,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.8,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.67,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.61,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.62,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.62,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.9,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.86,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.52,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.83,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.6,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.56,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.41,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.67,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.27,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.56,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.7,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.5,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.29,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.42,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2001,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.98,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2002,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.6,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2003,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.37,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2004,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.77,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2005,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.95,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2006,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.02,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2007,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.95,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2008,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.45,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2009,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.98,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2010,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.92,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2011,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.87,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2000,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.64,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.22,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.6,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.58,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.12,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.14,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.13,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.07,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.71,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.59,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.96,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.96,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.63,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.86,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.81,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.14,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Lithuania',
# ...
#  {'TIME': 2011,
#   'GEO': 'Netherlands',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.93,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.66,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.74,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.53,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.48,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.44,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.4,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.33,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.47,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.98,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.91,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.8,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.87,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2001,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.42,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2002,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2003,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.35,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2004,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2005,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.47,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2006,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.25,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2007,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.91,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2008,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.08,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2009,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.09,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2010,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.17,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2011,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.42,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2001,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.39,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2002,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.33,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2003,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2004,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.1,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2005,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.21,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2006,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.07,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2007,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.1,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2008,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.89,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2009,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.79,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2010,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.62,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2011,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.27,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2000,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 2.88,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.25,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.51,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.45,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.28,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.48,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': 'u'},
#  {'TIME': 2007,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': 'u'},
#  {'TIME': 2009,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.53,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.07,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.86,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.76,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.8,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.74,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.73,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.72,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.2,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.69,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.92,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2001,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.99,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2002,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.31,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2003,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.3,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2004,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.19,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2005,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.85,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2006,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.8,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2007,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.62,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2008,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.61,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2009,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.09,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2010,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.22,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2011,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.06,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2000,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.89,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.06,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.22,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.43,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.42,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.3,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.18,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.9,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.1,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.81,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.85,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.76,
#   'Flag and Footnotes': nan}]

# %%
#insert documents in the collection
collection.insert_many(df.to_dict("records"))

# %%
#Check that we have a non empty collection.
db.list_collection_names()
# Out:
# ['edu']

# %% [markdown]
# To recap, we have databases containing collections. A collection is made up of documents. Each document is made up of fields.

# %% [markdown]
# ### Retrieving data

# %%
collection.find_one() #Returns first document in the collection
# Out:
# {'_id': ObjectId('615434f322ce1956b4fc352d'),
#  'TIME': 2000,
#  'GEO': 'European Union (28 countries)',
#  'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#  'Value': nan,
#  'Flag and Footnotes': nan}

# %% [markdown]
# To get more than a single document as the result of a query we use the find() method. find() returns a Cursor instance, which allows us to iterate over all matching documents.

# %%
collection.find()

# %%
[d for d in collection.find()]
# Out:
# [{'_id': ObjectId('615434f322ce1956b4fc352d'),
#   'TIME': 2000,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc352e'),
#   'TIME': 2001,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc352f'),
#   'TIME': 2002,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.0,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3530'),
#   'TIME': 2003,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.03,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3531'),
#   'TIME': 2004,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3532'),
#   'TIME': 2005,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.92,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3533'),
#   'TIME': 2006,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.91,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3534'),
#   'TIME': 2007,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.92,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3535'),
#   'TIME': 2008,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.04,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3536'),
#   'TIME': 2009,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3537'),
#   'TIME': 2010,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3538'),
#   'TIME': 2011,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.25,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3539'),
#   'TIME': 2000,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.91,
#   'Flag and Footnotes': 's'},
#  {'_id': ObjectId('615434f322ce1956b4fc353a'),
#   'TIME': 2001,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.99,
#   'Flag and Footnotes': 's'},
#  {'_id': ObjectId('615434f322ce1956b4fc353b'),
#   'TIME': 2002,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.0,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc353c'),
#   'TIME': 2003,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.04,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc353d'),
#   'TIME': 2004,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc353e'),
#   'TIME': 2005,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.92,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc353f'),
#   'TIME': 2006,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.91,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3540'),
#   'TIME': 2007,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.93,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3541'),
#   'TIME': 2008,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.04,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3542'),
#   'TIME': 2009,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3543'),
#   'TIME': 2010,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3544'),
#   'TIME': 2011,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.25,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3545'),
#   'TIME': 2000,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': 's'},
#  {'_id': ObjectId('615434f322ce1956b4fc3546'),
#   'TIME': 2001,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': 's'},
#  {'_id': ObjectId('615434f322ce1956b4fc3547'),
#   'TIME': 2002,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.03,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3548'),
#   'TIME': 2003,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.06,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3549'),
#   'TIME': 2004,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc354a'),
#   'TIME': 2005,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc354b'),
#   'TIME': 2006,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.93,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc354c'),
#   'TIME': 2007,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc354d'),
#   'TIME': 2008,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.06,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc354e'),
#   'TIME': 2009,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc354f'),
#   'TIME': 2010,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.46,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3550'),
#   'TIME': 2011,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3551'),
#   'TIME': 2000,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3552'),
#   'TIME': 2001,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3553'),
#   'TIME': 2002,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.87,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3554'),
#   'TIME': 2003,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.89,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3555'),
#   'TIME': 2004,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.8,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3556'),
#   'TIME': 2005,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3557'),
#   'TIME': 2006,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.69,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3558'),
#   'TIME': 2007,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.79,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3559'),
#   'TIME': 2008,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc355a'),
#   'TIME': 2009,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc355b'),
#   'TIME': 2010,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.28,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc355c'),
#   'TIME': 2011,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc355d'),
#   'TIME': 2000,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc355e'),
#   'TIME': 2001,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc355f'),
#   'TIME': 2002,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.86,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3560'),
#   'TIME': 2003,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.89,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3561'),
#   'TIME': 2004,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.8,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3562'),
#   'TIME': 2005,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3563'),
#   'TIME': 2006,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.69,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3564'),
#   'TIME': 2007,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.79,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3565'),
#   'TIME': 2008,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3566'),
#   'TIME': 2009,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3567'),
#   'TIME': 2010,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.28,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3568'),
#   'TIME': 2011,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3569'),
#   'TIME': 2000,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': 'u'},
#  {'_id': ObjectId('615434f322ce1956b4fc356a'),
#   'TIME': 2001,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': 's'},
#  {'_id': ObjectId('615434f322ce1956b4fc356b'),
#   'TIME': 2002,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.01,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc356c'),
#   'TIME': 2003,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.04,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc356d'),
#   'TIME': 2004,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.96,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc356e'),
#   'TIME': 2005,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.89,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc356f'),
#   'TIME': 2006,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.87,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3570'),
#   'TIME': 2007,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.81,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3571'),
#   'TIME': 2008,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3572'),
#   'TIME': 2009,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3573'),
#   'TIME': 2010,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.29,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3574'),
#   'TIME': 2011,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.16,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3575'),
#   'TIME': 2000,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': 'u'},
#  {'_id': ObjectId('615434f322ce1956b4fc3576'),
#   'TIME': 2001,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.97,
#   'Flag and Footnotes': 's'},
#  {'_id': ObjectId('615434f322ce1956b4fc3577'),
#   'TIME': 2002,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.0,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3578'),
#   'TIME': 2003,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.04,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3579'),
#   'TIME': 2004,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc357a'),
#   'TIME': 2005,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.89,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc357b'),
#   'TIME': 2006,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.87,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc357c'),
#   'TIME': 2007,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.8,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc357d'),
#   'TIME': 2008,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc357e'),
#   'TIME': 2009,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc357f'),
#   'TIME': 2010,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.28,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3580'),
#   'TIME': 2011,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3581'),
#   'TIME': 2000,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': 'u'},
#  {'_id': ObjectId('615434f322ce1956b4fc3582'),
#   'TIME': 2001,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.99,
#   'Flag and Footnotes': 'i'},
#  {'_id': ObjectId('615434f322ce1956b4fc3583'),
#   'TIME': 2002,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc3584'),
#   'TIME': 2003,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.02,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc3585'),
#   'TIME': 2004,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.95,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc3586'),
#   'TIME': 2005,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.92,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc3587'),
#   'TIME': 2006,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.98,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc3588'),
#   'TIME': 2007,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.0,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc3589'),
#   'TIME': 2008,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.43,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc358a'),
#   'TIME': 2009,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.57,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc358b'),
#   'TIME': 2010,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.58,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc358c'),
#   'TIME': 2011,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.55,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc358d'),
#   'TIME': 2000,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.88,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc358e'),
#   'TIME': 2001,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.7,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc358f'),
#   'TIME': 2002,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.94,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3590'),
#   'TIME': 2003,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.09,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3591'),
#   'TIME': 2004,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.4,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3592'),
#   'TIME': 2005,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3593'),
#   'TIME': 2006,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.04,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3594'),
#   'TIME': 2007,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.88,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3595'),
#   'TIME': 2008,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.44,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3596'),
#   'TIME': 2009,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.58,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3597'),
#   'TIME': 2010,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.1,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3598'),
#   'TIME': 2011,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.82,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3599'),
#   'TIME': 2000,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.83,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc359a'),
#   'TIME': 2001,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.93,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc359b'),
#   'TIME': 2002,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.15,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc359c'),
#   'TIME': 2003,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.32,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc359d'),
#   'TIME': 2004,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.2,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc359e'),
#   'TIME': 2005,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.08,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc359f'),
#   'TIME': 2006,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.42,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35a0'),
#   'TIME': 2007,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.05,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35a1'),
#   'TIME': 2008,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.92,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35a2'),
#   'TIME': 2009,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.36,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35a3'),
#   'TIME': 2010,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35a4'),
#   'TIME': 2011,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.51,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35a5'),
#   'TIME': 2000,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.28,
#   'Flag and Footnotes': 'i'},
#  {'_id': ObjectId('615434f322ce1956b4fc35a6'),
#   'TIME': 2001,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.44,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc35a7'),
#   'TIME': 2002,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.44,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc35a8'),
#   'TIME': 2003,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.33,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35a9'),
#   'TIME': 2004,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.43,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35aa'),
#   'TIME': 2005,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.3,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc35ab'),
#   'TIME': 2006,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.97,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc35ac'),
#   'TIME': 2007,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.81,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc35ad'),
#   'TIME': 2008,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.68,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc35ae'),
#   'TIME': 2009,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.74,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc35af'),
#   'TIME': 2010,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.81,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc35b0'),
#   'TIME': 2011,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.75,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc35b1'),
#   'TIME': 2000,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.45,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35b2'),
#   'TIME': 2001,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.51,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35b3'),
#   'TIME': 2002,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35b4'),
#   'TIME': 2003,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.74,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35b5'),
#   'TIME': 2004,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.62,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35b6'),
#   'TIME': 2005,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.57,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35b7'),
#   'TIME': 2006,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.43,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35b8'),
#   'TIME': 2007,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.49,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35b9'),
#   'TIME': 2008,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.57,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35ba'),
#   'TIME': 2009,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.06,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35bb'),
#   'TIME': 2010,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.08,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35bc'),
#   'TIME': 2011,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35bd'),
#   'TIME': 2000,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.57,
#   'Flag and Footnotes': 'i'},
#  {'_id': ObjectId('615434f322ce1956b4fc35be'),
#   'TIME': 2001,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.24,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35bf'),
#   'TIME': 2002,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.47,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35c0'),
#   'TIME': 2003,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.29,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35c1'),
#   'TIME': 2004,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.92,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35c2'),
#   'TIME': 2005,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.88,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35c3'),
#   'TIME': 2006,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.7,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35c4'),
#   'TIME': 2007,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc35c5'),
#   'TIME': 2008,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.61,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35c6'),
#   'TIME': 2009,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.03,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35c7'),
#   'TIME': 2010,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.66,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35c8'),
#   'TIME': 2011,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.16,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35c9'),
#   'TIME': 2000,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.29,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35ca'),
#   'TIME': 2001,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35cb'),
#   'TIME': 2002,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.27,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35cc'),
#   'TIME': 2003,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.35,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35cd'),
#   'TIME': 2004,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.66,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35ce'),
#   'TIME': 2005,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35cf'),
#   'TIME': 2006,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.73,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35d0'),
#   'TIME': 2007,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.92,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35d1'),
#   'TIME': 2008,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.67,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35d2'),
#   'TIME': 2009,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.43,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35d3'),
#   'TIME': 2010,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.41,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35d4'),
#   'TIME': 2011,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.15,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35d5'),
#   'TIME': 2000,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.71,
#   'Flag and Footnotes': 'i'},
#  {'_id': ObjectId('615434f322ce1956b4fc35d6'),
#   'TIME': 2001,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.5,
#   'Flag and Footnotes': 'i'},
#  {'_id': ObjectId('615434f322ce1956b4fc35d7'),
#   'TIME': 2002,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.57,
#   'Flag and Footnotes': 'i'},
#  {'_id': ObjectId('615434f322ce1956b4fc35d8'),
#   'TIME': 2003,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.56,
#   'Flag and Footnotes': 'i'},
#  {'_id': ObjectId('615434f322ce1956b4fc35d9'),
#   'TIME': 2004,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.83,
#   'Flag and Footnotes': 'i'},
#  {'_id': ObjectId('615434f322ce1956b4fc35da'),
#   'TIME': 2005,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.09,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35db'),
#   'TIME': 2006,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35dc'),
#   'TIME': 2007,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35dd'),
#   'TIME': 2008,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35de'),
#   'TIME': 2009,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35df'),
#   'TIME': 2010,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35e0'),
#   'TIME': 2011,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35e1'),
#   'TIME': 2000,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.28,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35e2'),
#   'TIME': 2001,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35e3'),
#   'TIME': 2002,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35e4'),
#   'TIME': 2003,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.28,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35e5'),
#   'TIME': 2004,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35e6'),
#   'TIME': 2005,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.23,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35e7'),
#   'TIME': 2006,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.26,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35e8'),
#   'TIME': 2007,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.34,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35e9'),
#   'TIME': 2008,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.62,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35ea'),
#   'TIME': 2009,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35eb'),
#   'TIME': 2010,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35ec'),
#   'TIME': 2011,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.82,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35ed'),
#   'TIME': 2000,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.04,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35ee'),
#   'TIME': 2001,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.95,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35ef'),
#   'TIME': 2002,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.9,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35f0'),
# ...
#  {'_id': ObjectId('615434f322ce1956b4fc3669'),
#   'TIME': 2004,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc366a'),
#   'TIME': 2005,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.47,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc366b'),
#   'TIME': 2006,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.25,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc366c'),
#   'TIME': 2007,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.91,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc366d'),
#   'TIME': 2008,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.08,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc366e'),
#   'TIME': 2009,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc366f'),
#   'TIME': 2010,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.17,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc3670'),
#   'TIME': 2011,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3671'),
#   'TIME': 2000,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.42,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc3672'),
#   'TIME': 2001,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.39,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc3673'),
#   'TIME': 2002,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.33,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc3674'),
#   'TIME': 2003,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc3675'),
#   'TIME': 2004,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.1,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc3676'),
#   'TIME': 2005,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.21,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc3677'),
#   'TIME': 2006,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.07,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc3678'),
#   'TIME': 2007,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.1,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc3679'),
#   'TIME': 2008,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.89,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc367a'),
#   'TIME': 2009,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.79,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc367b'),
#   'TIME': 2010,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.62,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc367c'),
#   'TIME': 2011,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.27,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc367d'),
#   'TIME': 2000,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 2.88,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc367e'),
#   'TIME': 2001,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc367f'),
#   'TIME': 2002,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.51,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3680'),
#   'TIME': 2003,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.45,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3681'),
#   'TIME': 2004,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.28,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3682'),
#   'TIME': 2005,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.48,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3683'),
#   'TIME': 2006,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': 'u'},
#  {'_id': ObjectId('615434f322ce1956b4fc3684'),
#   'TIME': 2007,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3685'),
#   'TIME': 2008,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': 'u'},
#  {'_id': ObjectId('615434f322ce1956b4fc3686'),
#   'TIME': 2009,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3687'),
#   'TIME': 2010,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.53,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3688'),
#   'TIME': 2011,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.07,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3689'),
#   'TIME': 2000,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc368a'),
#   'TIME': 2001,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.86,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc368b'),
#   'TIME': 2002,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.76,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc368c'),
#   'TIME': 2003,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.8,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc368d'),
#   'TIME': 2004,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.74,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc368e'),
#   'TIME': 2005,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.73,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc368f'),
#   'TIME': 2006,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.72,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3690'),
#   'TIME': 2007,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3691'),
#   'TIME': 2008,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.2,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3692'),
#   'TIME': 2009,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.69,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3693'),
#   'TIME': 2010,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3694'),
#   'TIME': 2011,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3695'),
#   'TIME': 2000,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.92,
#   'Flag and Footnotes': 'i'},
#  {'_id': ObjectId('615434f322ce1956b4fc3696'),
#   'TIME': 2001,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.99,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc3697'),
#   'TIME': 2002,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.31,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc3698'),
#   'TIME': 2003,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.3,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc3699'),
#   'TIME': 2004,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.19,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc369a'),
#   'TIME': 2005,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.85,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc369b'),
#   'TIME': 2006,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.8,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc369c'),
#   'TIME': 2007,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.62,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc369d'),
#   'TIME': 2008,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.61,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc369e'),
#   'TIME': 2009,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc369f'),
#   'TIME': 2010,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.22,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc36a0'),
#   'TIME': 2011,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.06,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc36a1'),
#   'TIME': 2000,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.89,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc36a2'),
#   'TIME': 2001,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.06,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc36a3'),
#   'TIME': 2002,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.22,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc36a4'),
#   'TIME': 2003,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.43,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc36a5'),
#   'TIME': 2004,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.42,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc36a6'),
#   'TIME': 2005,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.3,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc36a7'),
#   'TIME': 2006,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.18,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc36a8'),
#   'TIME': 2007,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.9,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc36a9'),
#   'TIME': 2008,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.1,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc36aa'),
#   'TIME': 2009,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.81,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc36ab'),
#   'TIME': 2010,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.85,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc36ac'),
#   'TIME': 2011,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.76,
#   'Flag and Footnotes': nan}]

# %% [markdown]
# If we just want to know how many documents match a query we can perform a count() operation instead of a full query. We can get a count of all of the documents in a collection:

# %%
collection.count_documents({})
# Out:
# 384

# %% [markdown]
# ### Basic queries

# %% [markdown]
# Querying in pymongo uses .find()

# %%
[d for d in collection.find({"TIME":2009})]
# Out:
# [{'_id': ObjectId('615434f322ce1956b4fc3536'),
#   'TIME': 2009,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3542'),
#   'TIME': 2009,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc354e'),
#   'TIME': 2009,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc355a'),
#   'TIME': 2009,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3566'),
#   'TIME': 2009,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3572'),
#   'TIME': 2009,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc357e'),
#   'TIME': 2009,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc358a'),
#   'TIME': 2009,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.57,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc3596'),
#   'TIME': 2009,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.58,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35a2'),
#   'TIME': 2009,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.36,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35ae'),
#   'TIME': 2009,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.74,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc35ba'),
#   'TIME': 2009,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.06,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35c6'),
#   'TIME': 2009,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.03,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35d2'),
#   'TIME': 2009,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.43,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35de'),
#   'TIME': 2009,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35ea'),
#   'TIME': 2009,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35f6'),
#   'TIME': 2009,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.9,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3602'),
#   'TIME': 2009,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.7,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc360e'),
#   'TIME': 2009,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.98,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc361a'),
#   'TIME': 2009,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.59,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3626'),
#   'TIME': 2009,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.64,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3632'),
#   'TIME': 2009,
#   'GEO': 'Luxembourg',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc363e'),
#   'TIME': 2009,
#   'GEO': 'Hungary',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.12,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc364a'),
#   'TIME': 2009,
#   'GEO': 'Malta',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3656'),
#   'TIME': 2009,
#   'GEO': 'Netherlands',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.95,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3662'),
#   'TIME': 2009,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc366e'),
#   'TIME': 2009,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc367a'),
#   'TIME': 2009,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.79,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc3686'),
#   'TIME': 2009,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3692'),
#   'TIME': 2009,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.69,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc369e'),
#   'TIME': 2009,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc36aa'),
#   'TIME': 2009,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.81,
#   'Flag and Footnotes': nan}]

# %% [markdown]
# Observe that it finds exact matches (including data type)

# %%
[d for d in collection.find({"TIME":"2009"})]
# Out:
# []

# %%
[d for d in collection.find({"GEO":"Spain"})]
# Out:
# [{'_id': ObjectId('615434f322ce1956b4fc35e1'),
#   'TIME': 2000,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.28,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35e2'),
#   'TIME': 2001,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35e3'),
#   'TIME': 2002,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35e4'),
#   'TIME': 2003,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.28,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35e5'),
#   'TIME': 2004,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35e6'),
#   'TIME': 2005,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.23,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35e7'),
#   'TIME': 2006,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.26,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35e8'),
#   'TIME': 2007,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.34,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35e9'),
#   'TIME': 2008,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.62,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35ea'),
#   'TIME': 2009,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35eb'),
#   'TIME': 2010,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35ec'),
#   'TIME': 2011,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.82,
#   'Flag and Footnotes': nan}]

# %%
[d for d in collection.find({"GEO":"SPAIN"})]
# Out:
# []

# %% [markdown]
# Operations include *gt* (greater than), *gte* (greater than equal), *lt* (lesser than), *lte* (lesser than equal), *ne* (not equal), *nin* (not in a list), *regex* (regular expression), *exists*, *not*, *or*, *and*, etc. Let us see some examples:

# %%
[d for d in collection.find({"TIME":{"$gte":2009}})]
# Out:
# [{'_id': ObjectId('615434f322ce1956b4fc3536'),
#   'TIME': 2009,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3537'),
#   'TIME': 2010,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3538'),
#   'TIME': 2011,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.25,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3542'),
#   'TIME': 2009,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3543'),
#   'TIME': 2010,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3544'),
#   'TIME': 2011,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.25,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc354e'),
#   'TIME': 2009,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc354f'),
#   'TIME': 2010,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.46,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3550'),
#   'TIME': 2011,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc355a'),
#   'TIME': 2009,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc355b'),
#   'TIME': 2010,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.28,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc355c'),
#   'TIME': 2011,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3566'),
#   'TIME': 2009,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3567'),
#   'TIME': 2010,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.28,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3568'),
#   'TIME': 2011,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3572'),
#   'TIME': 2009,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3573'),
#   'TIME': 2010,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.29,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3574'),
#   'TIME': 2011,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.16,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc357e'),
#   'TIME': 2009,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc357f'),
#   'TIME': 2010,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.28,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc3580'),
#   'TIME': 2011,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('615434f322ce1956b4fc358a'),
#   'TIME': 2009,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.57,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc358b'),
#   'TIME': 2010,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.58,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc358c'),
#   'TIME': 2011,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.55,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc3596'),
#   'TIME': 2009,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.58,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3597'),
#   'TIME': 2010,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.1,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3598'),
#   'TIME': 2011,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.82,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35a2'),
#   'TIME': 2009,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.36,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35a3'),
#   'TIME': 2010,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35a4'),
#   'TIME': 2011,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.51,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35ae'),
#   'TIME': 2009,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.74,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc35af'),
#   'TIME': 2010,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.81,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc35b0'),
#   'TIME': 2011,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.75,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc35ba'),
#   'TIME': 2009,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.06,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35bb'),
#   'TIME': 2010,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.08,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35bc'),
#   'TIME': 2011,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35c6'),
#   'TIME': 2009,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.03,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35c7'),
#   'TIME': 2010,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.66,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35c8'),
#   'TIME': 2011,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.16,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35d2'),
#   'TIME': 2009,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.43,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35d3'),
#   'TIME': 2010,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.41,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35d4'),
#   'TIME': 2011,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.15,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35de'),
#   'TIME': 2009,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35df'),
#   'TIME': 2010,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35e0'),
#   'TIME': 2011,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35ea'),
#   'TIME': 2009,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35eb'),
#   'TIME': 2010,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35ec'),
#   'TIME': 2011,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.82,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35f6'),
#   'TIME': 2009,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.9,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35f7'),
#   'TIME': 2010,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.86,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc35f8'),
#   'TIME': 2011,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3602'),
#   'TIME': 2009,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.7,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3603'),
#   'TIME': 2010,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.5,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3604'),
#   'TIME': 2011,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.29,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc360e'),
#   'TIME': 2009,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.98,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc360f'),
#   'TIME': 2010,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.92,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc3610'),
#   'TIME': 2011,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.87,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc361a'),
#   'TIME': 2009,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.59,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc361b'),
#   'TIME': 2010,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.96,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc361c'),
#   'TIME': 2011,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.96,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3626'),
#   'TIME': 2009,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.64,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3627'),
#   'TIME': 2010,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.36,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3628'),
#   'TIME': 2011,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.17,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3632'),
#   'TIME': 2009,
#   'GEO': 'Luxembourg',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3633'),
#   'TIME': 2010,
#   'GEO': 'Luxembourg',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3634'),
#   'TIME': 2011,
#   'GEO': 'Luxembourg',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc363e'),
#   'TIME': 2009,
#   'GEO': 'Hungary',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.12,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc363f'),
#   'TIME': 2010,
#   'GEO': 'Hungary',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.9,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3640'),
#   'TIME': 2011,
#   'GEO': 'Hungary',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.71,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc364a'),
#   'TIME': 2009,
#   'GEO': 'Malta',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc364b'),
#   'TIME': 2010,
#   'GEO': 'Malta',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.74,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc364c'),
#   'TIME': 2011,
#   'GEO': 'Malta',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.96,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3656'),
#   'TIME': 2009,
#   'GEO': 'Netherlands',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.95,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3657'),
#   'TIME': 2010,
#   'GEO': 'Netherlands',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3658'),
#   'TIME': 2011,
#   'GEO': 'Netherlands',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.93,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3662'),
#   'TIME': 2009,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3663'),
#   'TIME': 2010,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.91,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3664'),
#   'TIME': 2011,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.8,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc366e'),
#   'TIME': 2009,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc366f'),
#   'TIME': 2010,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.17,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc3670'),
#   'TIME': 2011,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc367a'),
#   'TIME': 2009,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.79,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc367b'),
#   'TIME': 2010,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.62,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc367c'),
#   'TIME': 2011,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.27,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc3686'),
#   'TIME': 2009,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3687'),
#   'TIME': 2010,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.53,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3688'),
#   'TIME': 2011,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.07,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3692'),
#   'TIME': 2009,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.69,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3693'),
#   'TIME': 2010,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc3694'),
#   'TIME': 2011,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc369e'),
#   'TIME': 2009,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc369f'),
#   'TIME': 2010,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.22,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc36a0'),
#   'TIME': 2011,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.06,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('615434f322ce1956b4fc36aa'),
#   'TIME': 2009,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.81,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc36ab'),
#   'TIME': 2010,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.85,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('615434f322ce1956b4fc36ac'),
#   'TIME': 2011,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.76,
#   'Flag and Footnotes': nan}]

# %%
substring = r'Euro'
reg = substring
[(i["GEO"]) for i in collection.find({"GEO":{"$regex":reg}})]
# Out:
# ['European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)']

# %%
for item in collection.find({"GEO":{"$regex":reg}}):
     print (item['GEO'])
# Out:
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)

# %% [markdown]
# ### Update

# %% [markdown]
# In this section, several methods for updating and deleting documents are reveiwed:
#
# + Replace. This method finds the documents defined by query and **replaces** it by the new document.

# %%
#Insert One new Document
import numpy as np
doc = {'Flag and Footnotes': np.nan,
  'GEO': 'Catalunya',
  'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
  'TIME': 2017,
  'Value': np.nan}
collection.insert_one(doc)

# %%
for doc in collection.find({'GEO':"Catalunya"}):
    print (doc)
# Out:
# {'_id': ObjectId('6154507e22ce1956b4fc36ad'), 'Flag and Footnotes': nan, 'GEO': 'Catalunya', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'TIME': 2017, 'Value': nan}

# %%
#Replace first occurence
newdoc = {'Flag and Footnotes': np.nan,
  'GEO': 'Catalunya',
  'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
  'TIME': 2017,
  'Value': 15}
collection.replace_one({'GEO':"Catalunya"},newdoc)

for doc in collection.find({'GEO':"Catalunya"}):
    print (doc)
# Out:
# {'_id': ObjectId('6154507e22ce1956b4fc36ad'), 'Flag and Footnotes': nan, 'GEO': 'Catalunya', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'TIME': 2017, 'Value': 15}

# %% [markdown]
# If we don't want to write again all the document and just put the field that we want to change then we have to use **update_one** and adding a sub-command.  Let us check some of them:

# %% [markdown]
# + Sub-command **Set**:
#
# This statement updates in the document in collection where field matches value1 by replacing the value of the field field1 with value2. This operator will add the specified field or fields if they do not exist in this document or replace the existing value of the specified field(s) if they already exist.
#
# An upsert eliminates the need to perform a separate database call to check for the existence of a record before performing either an update or an insert operation. Typically update operations update existing documents, but in MongoDB, the update_one() operation can accept an upsert option as an argument. Upserts are a hybrid operation that use the query argument to determine the write operation:
#
# If the query matches an existing document(s), the upsert performs an update.
# If the query matches no document in the collection, the upsert inserts a single document.

# %%
#Update first occurrence
collection.update_one({'GEO':"Catalunya"},{"$set":{"Value":12}})

# %%
for doc in collection.find({'GEO':"Catalunya"}):
    print (doc)
# Out:
# {'_id': ObjectId('6154507e22ce1956b4fc36ad'), 'Flag and Footnotes': nan, 'GEO': 'Catalunya', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'TIME': 2017, 'Value': 12}

# %% [markdown]
# By default, if the filter doesn't return any document, nothing is inserted to database. If you want to insert it, then set the upsert flag to `True`

# %%
collection.update_one({'GEO':"Andorra"},{"$set":{"Value":12}},upsert = True)
for doc in collection.find({'GEO':"Andorra"}):
    print (doc)
# Out:
# {'_id': ObjectId('6154512dd87047bf2b704a8d'), 'GEO': 'Andorra', 'Value': 12}

# %% [markdown]
# + Sub-commnad **Unset**:
#
# The unset operator deletes a particular field. If documents match the initial query but do not have the field specified in the unset operation, there the statement has no effect on the document.

# %%
collection.update_one({'GEO':"Catalunya"},{"$unset":{"Flag and Footnotes":""}})

# %%
for doc in collection.find({'GEO':"Catalunya"}):
    print (doc)
# Out:
# {'_id': ObjectId('6154507e22ce1956b4fc36ad'), 'GEO': 'Catalunya', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'TIME': 2017, 'Value': 12}

# %% [markdown]
# ### Delete operations

# %% [markdown]
# We can remove elements by simply:

# %%
collection.delete_one({"GEO":"Andorra"})

# %%
for doc in collection.find({"GEO":"Andorra"}):
    print (doc)

# %% [markdown]
# And remove a collection by:

# %%
db.list_collection_names()
# Out:
# ['edu']

# %%
db.drop_collection("edu")
db.list_collection_names()
# Out:
# []

# %% [markdown]
# And remove a database by:

# %%
conn.list_database_names()
# Out:
# ['admin', 'local']

# %%
conn.drop_database('ads')
conn.list_database_names()
# Out:
# ['admin', 'local']

# %% [markdown]
# And finally close the connection with the database.

# %%
conn.close()
